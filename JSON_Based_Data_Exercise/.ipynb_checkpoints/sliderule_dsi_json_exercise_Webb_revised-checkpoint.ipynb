# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# + data source: http://jsonstudio.com/resources/
# ****

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
import pandas as pd # needed for DataFrames and pandas.read_json to read a JSON file at the top nested level
import json #needed for jason.load to load nested data as a string
from pandas.io.json import json_normalize #needed for json_normalize which extracts nested data in a string
import numpy as np #used below in an aggregation associated with a groupby

# %% [markdown]
# <font color=black></font>
# ## QUESTION 1: Find the 10 Countries with the Most Projects

# %%
# load json data using pandas.read_json into a dataframe because the target data are at the top level of the json file (i.e not nested)
world_bank_df = pd.read_json('data/world_bank_projects.json')

# %%
# Examine the DataFrame's components
#world_bank_df.info()

# View the DataFrame's header
#world_bank_df.head()

# %%
# Filter the most relevant columns from the parent DataFrame
projects = world_bank_df[['countrycode','countryshortname','project_name']]

# Change the index to the countrycode column for increased readability
projects = projects.set_index('countrycode')
projects.head()
# Out:
#                countryshortname  \
# countrycode
# ET                     Ethiopia
# TN                      Tunisia
# TV                       Tuvalu
# RY           Yemen, Republic of
# LS                      Lesotho
#
#                                                   project_name
# countrycode
# ET           Ethiopia General Education Quality Improvement...
# TN                   TN: DTF Social Protection Reforms Support
# TV           Tuvalu Aviation Investment Project - Additiona...
# RY            Gov't and Civil Society Organization Partnership
# LS           Second Private Sector Competitiveness and Econ...

# %%
# Group the filtered DataFrame to show the number of projects for each country
grouped_projects = projects.groupby(['countrycode','countryshortname'])['project_name'].count()

# Sort the number of projects per country in descending order and display the ten countries with the most projects
grouped_projects = grouped_projects.sort_values(ascending=False).head(10)

# Display the grouped and filtered DataFrame
grouped_projects
# Out:
# countrycode  countryshortname
# CN           China                 19
# ID           Indonesia             19
# VN           Vietnam               17
# IN           India                 16
# RY           Yemen, Republic of    13
# NP           Nepal                 12
# BD           Bangladesh            12
# MA           Morocco               12
# MZ           Mozambique            11
# 3A           Africa                11
# Name: project_name, dtype: int64

# %%
# Create a bar graph comparing the number of projects in different countries
gp_plot = grouped_projects.plot(kind='bar', title = 'Top Ten Countries with the Most Projects', rot = 80)
gp_plot.set_xlabel('Country Code')
gp_plot.set_ylabel('Number of Projects')
# Out:
# Text(0,0.5,'Number of Projects')

# %% [markdown]
# <font color=black></font>
# ## QUESTION 2: Find the Top 10 Major Project Themes (Using Column 'mjtheme_namecode')

# %%
# load json using jason.load from json as a string because the target data are nested
json_data = json.load((open('data/world_bank_projects.json')))

# %%
# Use json_normalize from pandas.io.json.json_normalize to extract the nested target data into a DataFrame
tdf = json_normalize(json_data, 'mjtheme_namecode')

# %%
# Examine the DataFrame's components
#tdf.info()

# View the DataFrame's header
#tdf.head()

# Sort the DataFrame and view it
tdf_sorted = tdf.sort_values('code')
tdf_sorted
# Out:
#      code                 name
# 458     1  Economic management
# 1235    1  Economic management
# 1230    1  Economic management
# 1229    1  Economic management
# 1218    1  Economic management
# 900     1  Economic management
# 648     1  Economic management
# 647     1  Economic management
# 1078    1  Economic management
# 1206    1  Economic management
# 1437    1
# 357     1  Economic management
# 363     1
# 1010    1  Economic management
# 784     1  Economic management
# 1024    1
# 88      1  Economic management
# 1045    1  Economic management
# 497     1  Economic management
# 1056    1  Economic management
# 1057    1  Economic management
# 1114    1
# 454     1  Economic management
# 453     1  Economic management
# 1257    1  Economic management
# 1260    1  Economic management
# 1212    1  Economic management
# 249     1  Economic management
# 841     1  Economic management
# 220     1  Economic management
# ...   ...                  ...
# 669     9    Urban development
# 1303    9    Urban development
# 1347    9    Urban development
# 460     9
# 1342    9    Urban development
# 183     9    Urban development
# 200     9    Urban development
# 1318    9    Urban development
# 1290    9    Urban development
# 585     9    Urban development
# 737     9    Urban development
# 822     9    Urban development
# 369     9    Urban development
# 597     9    Urban development
# 53      9    Urban development
# 598     9    Urban development
# 356     9    Urban development
# 354     9    Urban development
# 962     9    Urban development
# 738     9    Urban development
# 512     9    Urban development
# 742     9    Urban development
# 1428    9    Urban development
# 333     9
# 1426    9    Urban development
# 1425    9    Urban development
# 447     9    Urban development
# 739     9    Urban development
# 341     9    Urban development
# 1102    9    Urban development
#
# [1499 rows x 2 columns]

# %%
# Group the DataFrame by themes ('name' column)
tdf_grouped = tdf.groupby('name').count()

# Sort the grouped DataFrame in descending order using the 'code' column and display the ten most common themes
tdf_grouped = tdf_grouped.sort_values('code', ascending=False).head(10)
tdf_grouped
# Out:
#                                               code
# name
# Environment and natural resources management   223
# Rural development                              202
# Human development                              197
# Public sector governance                       184
# Social protection and risk management          158
# Financial and private sector development       130
#                                                122
# Social dev/gender/inclusion                    119
# Trade and integration                           72
# Urban development                               47

# %%
# Bar graph of the top ten major project themes
tdf_grouped_plot = tdf_grouped.plot(kind='bar', title = 'Top Ten Major Project Themes', rot = 80, legend=False)
tdf_grouped_plot.set_xlabel('Project Theme')
tdf_grouped_plot.set_ylabel('Number of Projects')
# Out:
# Text(0,0.5,'Number of Projects')

# %% [markdown]
# <font color=black></font>
# ## QUESTION 3 (Revised): Create a Dataframe with the Missing Names Filled in

# %%
# load json as a string because the target data are nested
json_data = json.load((open('data/world_bank_projects.json')))

# %%
# Use json_normalize to extract the nested target data
df = json_normalize(json_data, 'mjtheme_namecode')

# %%
# Examine the DataFrame's components
df.info()

# View the DataFrame's header
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
# code    1499 non-null object
# name    1499 non-null object
# dtypes: object(2)
# memory usage: 23.5+ KB
#   code                                   name
# 0    8                      Human development
# 1   11
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %%
# Sort and create a new version of the original DataFrame to use for merging to replace empty strings in the name column
df2 = df.sort_values(by=['code'])
# Verify the new DataFrame and the presence of empty strings in the name column
df2
# Out:
#      code                 name
# 458     1  Economic management
# 1235    1  Economic management
# 1230    1  Economic management
# 1229    1  Economic management
# 1218    1  Economic management
# 900     1  Economic management
# 648     1  Economic management
# 647     1  Economic management
# 1078    1  Economic management
# 1206    1  Economic management
# 1437    1
# 357     1  Economic management
# 363     1
# 1010    1  Economic management
# 784     1  Economic management
# 1024    1
# 88      1  Economic management
# 1045    1  Economic management
# 497     1  Economic management
# 1056    1  Economic management
# 1057    1  Economic management
# 1114    1
# 454     1  Economic management
# 453     1  Economic management
# 1257    1  Economic management
# 1260    1  Economic management
# 1212    1  Economic management
# 249     1  Economic management
# 841     1  Economic management
# 220     1  Economic management
# ...   ...                  ...
# 669     9    Urban development
# 1303    9    Urban development
# 1347    9    Urban development
# 460     9
# 1342    9    Urban development
# 183     9    Urban development
# 200     9    Urban development
# 1318    9    Urban development
# 1290    9    Urban development
# 585     9    Urban development
# 737     9    Urban development
# 822     9    Urban development
# 369     9    Urban development
# 597     9    Urban development
# 53      9    Urban development
# 598     9    Urban development
# 356     9    Urban development
# 354     9    Urban development
# 962     9    Urban development
# 738     9    Urban development
# 512     9    Urban development
# 742     9    Urban development
# 1428    9    Urban development
# 333     9
# 1426    9    Urban development
# 1425    9    Urban development
# 447     9    Urban development
# 739     9    Urban development
# 341     9    Urban development
# 1102    9    Urban development
#
# [1499 rows x 2 columns]

# %%
# Creating a lookup table for a merge
# Replace empty strings with NaN's so that NaN's can then be dropped
df['name'].replace('', np.nan,inplace=True)
#verify empty strings replaced with NaN's
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
# code    1499 non-null object
# name    1377 non-null object
# dtypes: object(2)
# memory usage: 23.5+ KB

# %%
# Drop NaN's from the DataFrame that will be the lookup table
df = df.dropna()
# Verify NaN's dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1377 entries, 0 to 1498
# Data columns (total 2 columns):
# code    1377 non-null object
# name    1377 non-null object
# dtypes: object(2)
# memory usage: 32.3+ KB

# %%
# Drop rows with the same contents to create small lookup table
df = df.drop_duplicates()
# Verify the new small lookup table
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 0 to 252
# Data columns (total 2 columns):
# code    11 non-null object
# name    11 non-null object
# dtypes: object(2)
# memory usage: 264.0+ bytes
#     code                                          name
# 0      8                             Human development
# 2      1                           Economic management
# 3      6         Social protection and risk management
# 4      5                         Trade and integration
# 5      2                      Public sector governance
# 6     11  Environment and natural resources management
# 8      7                   Social dev/gender/inclusion
# 11     4      Financial and private sector development
# 18    10                             Rural development
# 53     9                             Urban development
# 252    3                                   Rule of law

# %%
# Merge original DataFrame = df2 with lookup table DataFrame = df

df3 = pd.merge(df, df2, on='code', how = 'left')
df3.info()
df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499 entries, 0 to 1498
# Data columns (total 3 columns):
# code      1499 non-null object
# name_x    1499 non-null object
# name_y    1499 non-null object
# dtypes: object(3)
# memory usage: 46.8+ KB
#      code             name_x             name_y
# 0       8  Human development  Human development
# 1       8  Human development  Human development
# 2       8  Human development  Human development
# 3       8  Human development  Human development
# 4       8  Human development  Human development
# 5       8  Human development  Human development
# 6       8  Human development  Human development
# 7       8  Human development  Human development
# 8       8  Human development  Human development
# 9       8  Human development  Human development
# 10      8  Human development  Human development
# 11      8  Human development  Human development
# 12      8  Human development  Human development
# 13      8  Human development  Human development
# 14      8  Human development  Human development
# 15      8  Human development  Human development
# 16      8  Human development  Human development
# 17      8  Human development  Human development
# 18      8  Human development  Human development
# 19      8  Human development  Human development
# 20      8  Human development  Human development
# 21      8  Human development  Human development
# 22      8  Human development  Human development
# 23      8  Human development  Human development
# 24      8  Human development  Human development
# 25      8  Human development  Human development
# 26      8  Human development  Human development
# 27      8  Human development  Human development
# 28      8  Human development  Human development
# 29      8  Human development  Human development
# ...   ...                ...                ...
# 1469    9  Urban development  Urban development
# 1470    9  Urban development  Urban development
# 1471    9  Urban development  Urban development
# 1472    9  Urban development  Urban development
# 1473    9  Urban development  Urban development
# 1474    9  Urban development  Urban development
# 1475    9  Urban development  Urban development
# 1476    9  Urban development  Urban development
# 1477    9  Urban development
# 1478    9  Urban development  Urban development
# 1479    9  Urban development  Urban development
# 1480    9  Urban development  Urban development
# 1481    9  Urban development  Urban development
# 1482    9  Urban development  Urban development
# 1483    9  Urban development  Urban development
# 1484    3        Rule of law        Rule of law
# 1485    3        Rule of law
# 1486    3        Rule of law        Rule of law
# 1487    3        Rule of law
# 1488    3        Rule of law
# 1489    3        Rule of law        Rule of law
# 1490    3        Rule of law        Rule of law
# 1491    3        Rule of law        Rule of law
# 1492    3        Rule of law        Rule of law
# 1493    3        Rule of law        Rule of law
# 1494    3        Rule of law        Rule of law
# 1495    3        Rule of law        Rule of law
# 1496    3        Rule of law        Rule of law
# 1497    3        Rule of law        Rule of law
# 1498    3        Rule of law        Rule of law
#
# [1499 rows x 3 columns]

# %%
# delete name_y column carried over from df2, the original DataFrame
df3 = df3.drop('name_y', axis=1)
# Verify two columns remain
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
# code      1499 non-null object
# name_x    1499 non-null object
# dtypes: object(2)
# memory usage: 35.1+ KB

# %%
# Renaming the columns of the merged DataFrame
df3.rename(columns = {'code':'code', 'name_x':'theme'}, inplace=True)

# %%
# Verifying the renamed columns
df3.head()
# Out:
#   code              theme
# 0    8  Human development
# 1    8  Human development
# 2    8  Human development
# 3    8  Human development
# 4    8  Human development

# %%
# Group the merged DataFrame by theme ('name' column)
df3_g = df3.groupby('theme').count()

# Sort the grouped DataFrame in descending order using the 'code' column and display the ten most common themes
result = df3_g.sort_values('code', ascending=False).head(10)
result
# Out:
#                                               code
# theme
# Environment and natural resources management   250
# Rural development                              216
# Human development                              210
# Public sector governance                       199
# Social protection and risk management          168
# Financial and private sector development       146
# Social dev/gender/inclusion                    130
# Trade and integration                           77
# Urban development                               50
# Economic management                             38

# %%
# Bar graph of the top ten major project themes after filling missing values
result_plot = result.plot(kind='bar', title = 'Top Ten Major Project Themes', rot = 80, legend=False)
result_plot.set_xlabel('Project Theme')
result_plot.set_ylabel('Number of Projects')
# Out:
# Text(0,0.5,'Number of Projects')
